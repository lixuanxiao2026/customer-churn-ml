# %% [markdown]
# # Executive Dashboard — Customer Churn
#
# **Optional:** High-level visual summary for stakeholders.
#
# Include:
# - Churn rate over time / by segment
# - Model performance summary
# - Top churn drivers
# - Retention recommendations

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/raw/churn-bigml-20_raw.csv")
df["Churn"] = df["Churn"].astype(int)

# Example: Churn by International Plan
sns.barplot(data=df, x="International plan", y="Churn", estimator=sum)
plt.title("Churn by International Plan")
plt.show()
