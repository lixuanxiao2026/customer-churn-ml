# %% [markdown]
# # 02 — Feature Engineering
# **Customer Churn Prediction Pipeline**
#
# This notebook walks through every step of feature engineering in detail, including:
# 1. Load & inspect cleaned data
# 2. Fix `Area code` (categorical encoding)
# 3. Original aggregation features
# 4. New business-derived features
# 5. Correlation analysis & feature removal
# 6. Train / test split
# 7. Scaling with RobustScaler
# 8. Class imbalance — SMOTE
# 9. Save outputs
#
# > **Outputs:** `data/processed/churn_train.csv`, `data/processed/churn_test.csv`, `models/scaler.pkl`

# %% [markdown]
# ## 0. Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
import joblib
import warnings
warnings.filterwarnings('ignore')

# Display settings
pd.set_option('display.max_columns', 50)
pd.set_option('display.float_format', '{:.4f}'.format)
sns.set_theme(style='whitegrid', palette='muted')

# Paths
RAW_PATH        = 'data/raw/churn-bigml-20_raw.csv'
CLEAN_PATH      = 'data/processed/churn_clean.csv'
TRAIN_OUT       = 'data/processed/churn_train.csv'
TEST_OUT        = 'data/processed/churn_test.csv'
SCALER_OUT      = 'models/scaler.pkl'
DROPPED_OUT     = 'models/dropped_correlated_cols.pkl'
TARGET          = 'Churn'
RANDOM_STATE    = 42
TEST_SIZE       = 0.2
CORR_THRESHOLD  = 0.95

print('Setup complete.')

# %% [markdown]
# ## 1. Load Cleaned Data

# %%
# Run preprocessing if clean file doesn't exist
if not Path(CLEAN_PATH).exists():
    import sys
    sys.path.append('..')
    from src.preprocessing import run_preprocessing_pipeline
    run_preprocessing_pipeline(RAW_PATH, CLEAN_PATH)
    print('Preprocessing ran automatically.')

df = pd.read_csv(CLEAN_PATH)
print(f'Shape: {df.shape}')
df.head()

# %%
# Quick summary
print('Dtypes:')
print(df.dtypes.value_counts())
print(f'\nMissing values: {df.isnull().sum().sum()}')
print(f'\nTarget distribution:')
print(df[TARGET].value_counts(normalize=True).rename({0: 'No Churn', 1: 'Churn'}).map('{:.1%}'.format))

# %% [markdown]
# ## 2. Fix Area Code — Categorical Encoding
#
# `Area code` contains values like 415, 408, 510. These are **labels**, not ordinal numbers — leaving them as numeric would incorrectly imply 510 > 415 > 408. We one-hot encode them instead.

# %%
print('Area code distribution before encoding:')
print(df['Area code'].value_counts())

# %%
df['Area code'] = df['Area code'].astype(str)
df = pd.get_dummies(df, columns=['Area code'], prefix='area', drop_first=True)

area_cols = [c for c in df.columns if c.startswith('area_')]
print(f'New area columns: {area_cols}')
df[area_cols].head()

# %% [markdown]
# ## 3. Original Aggregation Features

# %%
# 3a. Total minutes across all periods
df['total_minutes'] = (
    df['Total day minutes'] + df['Total eve minutes'] + df['Total night minutes']
)

# 3b. Total charge across all periods
df['total_charge'] = (
    df['Total day charge'] + df['Total eve charge'] + df['Total night charge']
)

# 3c. Calls per minute — usage intensity
total_calls = df['Total day calls'] + df['Total eve calls'] + df['Total night calls']
df['calls_per_minute'] = np.where(df['total_minutes'] > 0, total_calls / df['total_minutes'], 0)

print('Original features added: total_minutes, total_charge, calls_per_minute')
df[['total_minutes', 'total_charge', 'calls_per_minute']].describe()

# %%
# Visualise: do churners use more minutes / charge?
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
for ax, col in zip(axes, ['total_minutes', 'total_charge', 'calls_per_minute']):
    for label, grp in df.groupby(TARGET):
        grp[col].plot(kind='kde', ax=ax, label='Churn' if label == 1 else 'No Churn')
    ax.set_title(col)
    ax.legend()
plt.suptitle('Original Aggregation Features by Churn Label', y=1.02, fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. New Business-Derived Features
#
# Each feature below captures a specific churn signal identified from telecom domain knowledge.

# %% [markdown]
# ### 4a. `high_service_calls` — Strongest Single Churn Predictor

# %%
# Customers with >= 4 customer service calls are extremely likely to churn
df['high_service_calls'] = (df['Customer service calls'] >= 4).astype(int)

# Visualise churn rate by number of service calls
churn_by_calls = df.groupby('Customer service calls')[TARGET].mean().reset_index()

plt.figure(figsize=(8, 4))
bars = plt.bar(churn_by_calls['Customer service calls'], churn_by_calls[TARGET],
               color=['#e74c3c' if x >= 4 else '#3498db'
                      for x in churn_by_calls['Customer service calls']])
plt.axvline(3.5, color='red', linestyle='--', linewidth=1.5, label='Threshold = 4')
plt.xlabel('Number of Customer Service Calls')
plt.ylabel('Churn Rate')
plt.title('Churn Rate by Customer Service Calls\n(red bars = high_service_calls flag)')
plt.legend()
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f'{y:.0%}'))
plt.tight_layout()
plt.show()

print(f"high_service_calls=1 churn rate: {df[df['high_service_calls']==1][TARGET].mean():.1%}")
print(f"high_service_calls=0 churn rate: {df[df['high_service_calls']==0][TARGET].mean():.1%}")

# %% [markdown]
# ### 4b. International Plan Mismatch Features

# %%
# intl_plan_no_usage: has intl plan but never uses it → paying for nothing
df['intl_plan_no_usage'] = (
    (df['International plan'] == 1) & (df['Total intl minutes'] == 0)
).astype(int)

# intl_high_usage_no_plan: heavy intl usage but no plan → high unexpected bills
intl_75th = df['Total intl minutes'].quantile(0.75)
df['intl_high_usage_no_plan'] = (
    (df['International plan'] == 0) & (df['Total intl minutes'] > intl_75th)
).astype(int)

fig, axes = plt.subplots(1, 2, figsize=(10, 4))
for ax, feat, title in zip(
    axes,
    ['intl_plan_no_usage', 'intl_high_usage_no_plan'],
    ['Has Intl Plan But No Usage', 'Heavy Intl Usage Without Plan']
):
    churn_rates = df.groupby(feat)[TARGET].mean()
    churn_rates.index = ['No', 'Yes']
    churn_rates.plot(kind='bar', ax=ax, color=['#3498db', '#e74c3c'], rot=0)
    ax.set_title(title)
    ax.set_ylabel('Churn Rate')
    ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f'{y:.0%}'))
    for p in ax.patches:
        ax.annotate(f'{p.get_height():.1%}', (p.get_x() + p.get_width()/2, p.get_height()),
                    ha='center', va='bottom', fontsize=11)
plt.suptitle('Churn Rate by International Plan Mismatch', fontsize=13, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4c. `day_rate_per_minute` — Price Sensitivity

# %%
df['day_rate_per_minute'] = df['Total day charge'] / (df['Total day minutes'] + 1e-6)

plt.figure(figsize=(7, 4))
for label, grp in df.groupby(TARGET):
    grp['day_rate_per_minute'].plot(kind='kde', label='Churn' if label == 1 else 'No Churn')
plt.title('Day Rate Per Minute by Churn Label')
plt.xlabel('$/minute')
plt.legend()
plt.tight_layout()
plt.show()

print(df.groupby(TARGET)['day_rate_per_minute'].describe())

# %% [markdown]
# ### 4d. `vmail_mismatch` — Unused Plan Signal

# %%
df['vmail_mismatch'] = (
    (df['Voice mail plan'] == 1) & (df['Number vmail messages'] == 0)
).astype(int)

rates = df.groupby('vmail_mismatch')[TARGET].mean()
rates.index = ['No Mismatch', 'Has Mismatch']

plt.figure(figsize=(5, 4))
rates.plot(kind='bar', color=['#3498db', '#e74c3c'], rot=0)
plt.title('Churn Rate: Voicemail Plan Mismatch')
plt.ylabel('Churn Rate')
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f'{y:.0%}'))
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height():.1%}',
                       (p.get_x() + p.get_width()/2, p.get_height()),
                       ha='center', va='bottom', fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4e. `peak_usage_period` — Behavioural Segmentation

# %%
period_map = {
    'Total day minutes': 'peak_day',
    'Total eve minutes': 'peak_eve',
    'Total night minutes': 'peak_night'
}
peak = df[list(period_map.keys())].idxmax(axis=1).map(period_map)
dummies = pd.get_dummies(peak, prefix='peak').astype(int)
for col in ['peak_day', 'peak_eve', 'peak_night']:
    if col not in dummies.columns:
        dummies[col] = 0
df = pd.concat([df, dummies[['peak_day', 'peak_eve', 'peak_night']]], axis=1)

# Churn rate by peak period
peak_churn = pd.DataFrame({
    col: [df[df[col] == 1][TARGET].mean()] for col in ['peak_day', 'peak_eve', 'peak_night']
}).T
peak_churn.columns = ['Churn Rate']
peak_churn.index = ['Day Peak', 'Eve Peak', 'Night Peak']

plt.figure(figsize=(6, 4))
peak_churn.plot(kind='bar', legend=False, color='#3498db', rot=0, ax=plt.gca())
plt.title('Churn Rate by Peak Usage Period')
plt.ylabel('Churn Rate')
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f'{y:.0%}'))
plt.tight_layout()
plt.show()

print('Peak period distribution:')
print(peak.value_counts())

# %% [markdown]
# ## 5. Correlation Analysis & Feature Removal
#
# Some raw features are nearly perfectly correlated (e.g. `Total day minutes` and `Total day charge` have r ≈ 1.0 because charge = minutes × fixed rate). Keeping both adds no new information and causes multicollinearity in linear models.

# %%
# Select numeric features only
X_all = df.drop(columns=[TARGET]).select_dtypes(include=[np.number])

# Full heatmap (top correlated pairs)
corr = X_all.corr().abs()

# Find highly correlated pairs
upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
high_corr_pairs = (
    upper.stack()
    .reset_index()
    .rename(columns={'level_0': 'Feature 1', 'level_1': 'Feature 2', 0: 'Correlation'})
    .query('Correlation > 0.7')
    .sort_values('Correlation', ascending=False)
)
print('Feature pairs with r > 0.70:')
print(high_corr_pairs.to_string(index=False))

# %%
# Heatmap of top 15 most correlated features
top_feats = corr.mean().nlargest(15).index
plt.figure(figsize=(12, 9))
mask = np.triu(np.ones_like(corr.loc[top_feats, top_feats], dtype=bool))
sns.heatmap(
    corr.loc[top_feats, top_feats],
    mask=mask,
    annot=True, fmt='.2f', cmap='coolwarm',
    vmin=0, vmax=1, linewidths=0.5
)
plt.title('Feature Correlation Heatmap (Top 15)', fontsize=13)
plt.tight_layout()
plt.show()

# %%
# Drop one of each highly correlated pair (threshold = 0.95)
# This is computed on training data only — see Section 6
to_drop_preview = [
    col for col in upper.columns if any(upper[col] > CORR_THRESHOLD)
]
print(f'Features to drop (r > {CORR_THRESHOLD}): {to_drop_preview}')
print(f'Remaining features: {len(X_all.columns) - len(to_drop_preview)}')

# %% [markdown]
# ## 6. Train / Test Split
#
# **Important:** The split is performed here — **before** any fitting (scaler, correlation removal). This prevents data leakage.

# %%
X = df.drop(columns=[TARGET]).select_dtypes(include=[np.number])
y = df[TARGET]

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE,
    stratify=y
)

print(f'Train: {X_train.shape[0]} rows | Test: {X_test.shape[0]} rows')
print(f'Train churn rate: {y_train.mean():.1%}')
print(f'Test  churn rate: {y_test.mean():.1%}')

# %%
# Now remove correlated features — fit on TRAIN only
corr_train = X_train.corr().abs()
upper_train = corr_train.where(np.triu(np.ones(corr_train.shape), k=1).astype(bool))
dropped_cols = [col for col in upper_train.columns if any(upper_train[col] > CORR_THRESHOLD)]

X_train = X_train.drop(columns=dropped_cols)
X_test  = X_test.drop(columns=dropped_cols, errors='ignore')

print(f'Dropped {len(dropped_cols)} correlated features: {dropped_cols}')
print(f'Final feature count: {X_train.shape[1]}')

# %% [markdown]
# ## 7. Scaling — RobustScaler
#
# `RobustScaler` uses median and IQR instead of mean and std, making it more robust to outliers (e.g. customers with extremely high call volumes).

# %%
feature_cols = X_train.columns.tolist()
scaler = RobustScaler()

X_train_scaled = pd.DataFrame(
    scaler.fit_transform(X_train),
    columns=feature_cols, index=X_train.index
)
X_test_scaled = pd.DataFrame(
    scaler.transform(X_test),
    columns=feature_cols, index=X_test.index
)

# Before vs after comparison for one feature
fig, axes = plt.subplots(1, 2, figsize=(11, 4))
X_train['total_charge'].plot(kind='hist', bins=40, ax=axes[0], title='total_charge — Before Scaling')
X_train_scaled['total_charge'].plot(kind='hist', bins=40, ax=axes[1], title='total_charge — After RobustScaler', color='#e67e22')
plt.tight_layout()
plt.show()

print('Scaled train stats (should be centred near 0):')
print(X_train_scaled.describe().loc[['mean', 'std', 'min', 'max']].T.head(8))

# %%
# Save scaler and dropped columns list
Path('models').mkdir(parents=True, exist_ok=True)
joblib.dump(scaler, SCALER_OUT)
joblib.dump(dropped_cols, DROPPED_OUT)
print(f'Scaler saved      : {SCALER_OUT}')
print(f'Dropped cols saved: {DROPPED_OUT}')

# %% [markdown]
# ## 8. Class Imbalance — SMOTE
#
# The dataset has ~14% churn (minority class). Without correction, models learn to simply predict "No Churn" and still achieve high accuracy. SMOTE creates synthetic minority-class samples in the training set only — **never applied to the test set**.

# %%
# Show class imbalance before SMOTE
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

before_counts = y_train.value_counts()
axes[0].pie(
    before_counts,
    labels=['No Churn', 'Churn'],
    autopct='%1.1f%%',
    colors=['#3498db', '#e74c3c'],
    startangle=90
)
axes[0].set_title(f'Before SMOTE\n(n={len(y_train)})')

# Apply SMOTE
try:
    from imblearn.over_sampling import SMOTE
    sm = SMOTE(random_state=RANDOM_STATE)
    X_train_res, y_train_res = sm.fit_resample(X_train_scaled, y_train)
    X_train_final = pd.DataFrame(X_train_res, columns=feature_cols)
    y_train_final = pd.Series(y_train_res, name=TARGET)
    smote_applied = True
except ImportError:
    print('imbalanced-learn not installed. Skipping SMOTE.')
    print('Install with: pip install imbalanced-learn')
    X_train_final = X_train_scaled
    y_train_final = y_train
    smote_applied = False

after_counts = y_train_final.value_counts()
axes[1].pie(
    after_counts,
    labels=['No Churn', 'Churn'],
    autopct='%1.1f%%',
    colors=['#3498db', '#e74c3c'],
    startangle=90
)
axes[1].set_title(f'After SMOTE\n(n={len(y_train_final)})' if smote_applied else 'SMOTE skipped')

plt.suptitle('Class Distribution in Training Set', fontsize=13)
plt.tight_layout()
plt.show()

if smote_applied:
    print(f'Before: {dict(before_counts)}')
    print(f'After : {dict(after_counts)}')

# %% [markdown]
# ## 9. Final Feature Summary

# %%
print('=== Feature Engineering Summary ===')
print(f'Total features after engineering : {len(feature_cols)}')
print(f'Features dropped (high corr)     : {len(dropped_cols)} → {dropped_cols}')
print()
new_features = [
    'total_minutes', 'total_charge', 'calls_per_minute',
    'high_service_calls', 'intl_plan_no_usage', 'intl_high_usage_no_plan',
    'day_rate_per_minute', 'vmail_mismatch', 'peak_day', 'peak_eve', 'peak_night'
]
print('Engineered features in final set:')
for f in new_features:
    status = '✓' if f in feature_cols else '✗ (dropped — correlated)'
    print(f'  {status}  {f}')

print()
print(f'Train set: {len(X_train_final)} rows | churn rate: {y_train_final.mean():.1%}')
print(f'Test set : {len(X_test_scaled)} rows  | churn rate: {y_test.mean():.1%}')

# %% [markdown]
# ## 10. Save Outputs

# %%
Path('data/processed').mkdir(parents=True, exist_ok=True)

# Save train set (with SMOTE if applied)
train_out = X_train_final.copy()
train_out[TARGET] = y_train_final.values
train_out.to_csv(TRAIN_OUT, index=False)

# Save test set (NO SMOTE — real distribution)
test_out = X_test_scaled.copy()
test_out[TARGET] = y_test.values
test_out.to_csv(TEST_OUT, index=False)

print(f'✓ Train saved : {TRAIN_OUT}  ({len(train_out)} rows)')
print(f'✓ Test saved  : {TEST_OUT}  ({len(test_out)} rows)')
print(f'✓ Scaler      : {SCALER_OUT}')
print(f'✓ Dropped cols: {DROPPED_OUT}')
print()
print('Ready for 03_modeling.ipynb')
